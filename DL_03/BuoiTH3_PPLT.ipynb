# %%
#luu y cac file G.txt khong duoc chua DAU CACH giua cac bieu thuc
# Dau mui ten quy dinh la  "->"
# Chuoi nhap vao cung ko duoc chua DAU CACH 
# Day la code uu tien REDUCE

grammar = {}
#Nhap quy luat
temp = []
f = open("/content/sample_data/G.txt")
for line in f.readlines():
  #print(line)
  a = line.strip("\n").split("->")
  temp.append(a)
#print("temp",temp)
T = temp[-1][0]

# Gan lai grammar tu duoi len
for i in range(len(temp)-1,-1,-1):
  grammar[temp[i][1]] = temp [i][0]
print(grammar)

inp_str = input("Nhap bieu thu can phan tich cu phap:")
result = ""
action = []
print("result\tstring\taction")
for i in range(len(inp_str)):
  #print("i",i)
  #print(inp_str[i])
  result = result + inp_str[i]
  print("{result}\t{inp_str}\tshift ".format(result = result,inp_str = inp_str[i+1:]))
  #inp_str = inp_str[i+1:]
  for j in range(i,-1,-1):
    action = len(temp)
    for key in grammar.keys(): #duyet nguoc
      if result[j:] == key:
        result = result[:j] + grammar[key]
        print("{result}\t{inp_str}\t{action} ".format(result = result,inp_str = inp_str[i+1:],action = action))
      action -=1
fw = open("/content/sample_data/input.txt","w+")
if result == T:
  fw.write("Accepted")
else:
  fw.write("Fail")
f.close()
fw.close()
# Out:
# {'id': 'S', 'S * S': 'S', 'S + S': 'S'}
# Nhap bieu thu can phan tich cu phap:id + tri
# result	string	action
# i	d + tri	shift
# id	 + tri	shift
# S	 + tri	3
# S 	+ tri	shift
# S +	 tri	shift
# S + 	tri	shift
# S + t	ri	shift
# S + tr	i	shift
# S + tri		shift

# %% [markdown]
# **Các bước tạo file exe**

# %%
# !pip install cx_Freeze
# Out:
# ...
#      |████████████████████████████████| 102kB 2.6MB/s
# ...
#   Created wheel for cx-Freeze: filename=cx_Freeze-6.1-cp36-cp36m-linux_x86_64.whl size=174465 sha256=54f58e9f938e83fab4edc0cc10b96dafe3ccac6f5229d81201e50a35f89ef031
#   Stored in directory: /root/.cache/pip/wheels/47/77/d4/295ded38700f999d5d1093fde3ad760dba43d9ab1dd8d42d79
# Successfully built cx-Freeze
# ...

# %%
# !pip install idna

# %%
# !cd /content/sample_data/TH03_PPLT

# %%
# !python /content/sample_data/TH03_PPLT/setup.py build
# Out:
# running build
# running build_exe
# creating directory build/exe.linux-x86_64-3.6
# copying /usr/local/lib/python3.6/dist-packages/cx_Freeze/bases/Console -> build/exe.linux-x86_64-3.6/main
# creating directory build/exe.linux-x86_64-3.6/lib
# copying /usr/lib/x86_64-linux-gnu/libpython3.6m.so.1.0 -> build/exe.linux-x86_64-3.6/lib/libpython3.6m.so.1.0
# writing zip file build/exe.linux-x86_64-3.6/lib/library.zip
#
#   Name                      File
#   ----                      ----
# m BUILD_CONSTANTS
# m __future__                /usr/lib/python3.6/__future__.py
# m __startup__               /usr/local/lib/python3.6/dist-packages/cx_Freeze/initscripts/__startup__.py
# m _ast
# m _bisect
# m _blake2
# m _bootlocale               /usr/lib/python3.6/_bootlocale.py
# m _bz2                      /usr/lib/python3.6/lib-dynload/_bz2.cpython-36m-x86_64-linux-gnu.so
# m _codecs
# m _codecs_cn                /usr/lib/python3.6/lib-dynload/_codecs_cn.cpython-36m-x86_64-linux-gnu.so
# ...
